# %%
import numpy as np
data = np.array([1,2,3,4,5])
print(np.median(data))
# Out:
# 3.0

# %%
mean = np.mean(data)

# %%
print(mean)
# Out:
# 3.0

# %%
median = np.median(data)

# %%
print(median)
# Out:
# 3.0

# %%
max = np.max(data)

# %%
print(max)
# Out:
# 5

# %%
std_dev = np.std(data)

# %%
print(std_dev)
# Out:
# 1.4142135623730951

# %%
total = np.sum(data)

# %%
print(total)
# Out:
# 15

# %%
reshaped_array = data.reshape((5, 1))

# %%
print(reshaped_array)
# Out:
# [[1]
#  [2]
#  [3]
#  [4]
#  [5]]

# %%
array1 = np.array([1,2,3])
array2 = np.array([4,5,6])
concatenated = np.concatenate((array1,array2))

# %%
print(concatenated)
# Out:
# [1 2 3 4 5 6]

# %%
concatenated = np.linspace(0,10,5)

# %%
print(concatenated)
# Out:
# [ 0.   2.5  5.   7.5 10. ]

# %%
range_array = np.arange(0,10,2)

# %%
print(range_array)
# Out:
# [0 2 4 6 8]
