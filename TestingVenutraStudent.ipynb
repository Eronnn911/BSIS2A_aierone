# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split
from sklearn.metrics import mean_squared_error, r2_score
import matplotlib.pyplot as plt

# %%
data = pd.read_csv("https://raw.githubusercontent.com/Eronnn911/BSIS2A_aierone/refs/heads/main/StudentsPerformance1%20(1).csv")

# %%
data.head()
# Out:
#    math score  gender_male  race/ethnicity_group B  race/ethnicity_group C  \
# 0          72        False                    True                   False
# 1          69        False                   False                    True
# 2          90        False                    True                   False
# 3          47         True                   False                   False
# 4          76         True                   False                    True
#
#    race/ethnicity_group D  race/ethnicity_group E  \
# 0                   False                   False
# 1                   False                   False
# 2                   False                   False
# 3                   False                   False
# 4                   False                   False
#
#    parental level of education_bachelor's degree  \
# 0                                           True
# 1                                          False
# 2                                          False
# ...

# %%
features = ['gender', 'race/ethnicity', 'parental level of education', 'lunch', 'test preparation course', 'reading score', 'writing score']
target = 'math score'

# %%
data = pd.get_dummies(data, columns=features, drop_first=True)

# %%
X_train, X_test, y_train, y_test = train_test_split(data.drop(target, axis=1), data[target], test_size=0.2, random_state=42)

# %%
model = LinearRegression()

# %%
model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = model.predict(X_test)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)

# %%
print(f"Mean Squared Error: {mse}")
print(f"R-squared: {r2}")
# Out:
# Mean Squared Error: 1.1740086458060945e+24
# R-squared: -4.824592607685817e+21

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_test, y_pred, alpha=0.5)
plt.xlabel("Actual Math Score")
plt.ylabel("Predicted Math Score")
plt.title("Actual vs. Predicted Math Scores")
# Out:
# Text(0.5, 1.0, 'Actual vs. Predicted Math Scores')

# %%
plt.figure(figsize=(8, 6))
plt.scatter(y_pred, y_test - y_pred, alpha=0.5)
plt.xlabel("Predicted Math Score")
plt.ylabel("Residuals")
plt.title("Residuals vs. Predicted Math Scores")
plt.show()
