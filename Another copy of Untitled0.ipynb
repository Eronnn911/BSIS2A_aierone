# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('https://raw.githubusercontent.com/Eronnn911/BSIS2A_aierone/main/example.csv')

# %%
df.head()
# Out:
#    age   income  gender  purchased
# 1   23  12323.0  female        1.0
# 5   12   2312.0  female        1.0

# %%
df = pd.DataFrame({'A':[1,2,3], 'B': [4,5,6]})
print(df.head())
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
print(df.tail())
# Out:
#    A  B
# 0  1  4
# 1  2  5
# 2  3  6

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3 entries, 0 to 2
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   A       3 non-null      int64
#  1   B       3 non-null      int64
# dtypes: int64(2)
# memory usage: 176.0 bytes

# %%
print (df.describe())
# Out:
#          A    B
# count  3.0  3.0
# mean   2.0  5.0
# std    1.0  1.0
# min    1.0  4.0
# 25%    1.5  4.5
# 50%    2.0  5.0
# 75%    2.5  5.5
# max    3.0  6.0

# %%
print (df.shape)
# Out:
# (3, 2)

# %%
print(df.columns)
# Out:
# Index(['A', 'B'], dtype='object')

# %%
df.drop('age', axis=1)
# Out:
#     income  gender  purchased
# 0      NaN    male        1.0
# 1  12323.0  female        1.0
# 2   4423.0     NaN        0.0
# 3   1345.0  female        NaN
# 4  54523.0     NaN        1.0
# 5   2312.0  female        1.0

# %%
df_filna = df.fillna('n/a')

# %%
df_filna.head()
# Out:
#    age   income  gender purchased
# 0   32      n/a    male       1.0
# 1   23  12323.0  female       1.0
# 2   23   4423.0     n/a       0.0
# 3   44   1345.0  female       n/a
# 4   43  54523.0     n/a       1.0

# %%
df = df.dropna()

# %%
df.head()
# Out:
#    age   income  gender  purchased
# 0   32      NaN    male        1.0
# 1   23  12323.0  female        1.0
# 2   23   4423.0     NaN        0.0
# 3   44   1345.0  female        NaN
# 4   43  54523.0     NaN        1.0

# %%
df_sort = df.sort_values(by='age',ascending=True)

# %%
df_sort.head()
# Out:
#    age   income  gender  purchased
# 5   12   2312.0  female        1.0
# 1   23  12323.0  female        1.0
# 2   23   4423.0     NaN        0.0
# 0   32      NaN    male        1.0
# 4   43  54523.0     NaN        1.0

# %%
df_grouped = df.groupby('gender').min()

# %%
df_grouped.head()
# Out:
#         age  income  purchased
# gender
# female   12  2312.0        1.0

# %%
df_apply = df['gender'] = df['age'].apply(lambda x: x*2)

# %%
df_apply.head()
# Out:
# 1    46
# 5    24
# Name: age, dtype: int64

# %%
df1 = pd.DataFrame({'key':['age','gender',], 'values':[32,'male']})
df2 = pd.DataFrame({'key':['age','gender',], 'values':[23,'female']})

# %%
merge_df = pd.merge(df1,df2, on ='key')

# %%
merge_df.head()
# Out:
#       key values_x values_y
# 0     age       32       23
# 1  gender     male   female

# %%
pivot_df = df.pivot_table(values='age',index='gender',aggfunc='mean')

# %%
pivot_df.head()
# Out:
#          age
# gender
# 24      12.0
# 46      23.0
